# %%
from main import StockPriceOptimizer
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **1. Inspect Available Companies**

# %%
print("Loading dataset...")
df = pd.read_csv('stock_indexes.csv')

print("\nAvailable companies:")
print(df['Company'].unique())
# Out:
# Loading dataset...
#
# Available companies:
# ['AAPL' 'SBUX' 'MSFT' 'CSCO' 'QCOM' 'META' 'AMZN' 'TSLA' 'AMD' 'NFLX']

# %%
df['Company'].value_counts()
# Out:
# Company
# AAPL    2516
# SBUX    2516
# MSFT    2516
# CSCO    2516
# QCOM    2516
# META    2516
# AMZN    2516
# TSLA    2516
# AMD     2516
# NFLX    2516
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind='pie', title='Number of records per company')
plt.show()

# %% [markdown]
# **2. Initialize the Optimizer**

# %%
FILE_PATH = 'stock_indexes.csv'
optimizer = StockPriceOptimizer(csv_file_path=FILE_PATH)
print("\n Optimizer initialized successfully.")
# Out:
# Successfully loaded data from stock_indexes.csv
#
#  Optimizer initialized successfully.

# %% [markdown]
# **3. Run Analysis for MSFT**

# %%
print("\nRunning analysis for MSFT...")
TICKER_TO_ANALYZE = 'MSFT'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" MSFT analysis completed.")
# Out:
# Running analysis for MSFT...
#
# --- Starting Analysis for: MSFT ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 4.515766
#   Weights: [ 1.10714034e+02 -3.62448613e-03 -3.85714129e-02 -4.91494030e+01
#   6.55885691e+01  6.31493493e+01]
# Method: Custom CG
#   Test MSE: 4.515349
#   Weights: [ 1.10714034e+02 -4.35254993e-03 -3.85314402e-02 -4.91617864e+01
#   6.56044680e+01  6.31438828e+01]
# Method: Least Squares
#   Test MSE: 4.515315
#   Weights: [ 1.10714034e+02 -3.77796172e-03 -3.87480881e-02 -4.91597874e+01
#   6.56118806e+01  6.31365362e+01]
# Generating plot for MSFT...
# Plot saved as 'MSFT_test_predictions.png'
# MSFT analysis completed.
#  MSFT analysis completed.

# %% [markdown]
# **4. Run Analysis for AAPL**

# %%
print("\nRunning analysis for AAPL...")
TICKER_TO_ANALYZE_2 = 'AAPL'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE_2,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" AAPL analysis completed.")
# Out:
# Running analysis for AAPL...
#
# --- Starting Analysis for: AAPL ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 1.145912
#   Weights: [ 5.46956509e+01 -2.93836544e-02 -2.11316266e-02 -2.44083378e+01
#   3.49831914e+01  2.94966127e+01]
# Method: Custom CG
#   Test MSE: 1.146102
#   Weights: [ 5.46956462e+01 -2.93429168e-02 -2.10649040e-02 -2.43873833e+01
#   3.49654192e+01  2.94933693e+01]
# Method: Least Squares
#   Test MSE: 1.146104
#   Weights: [ 5.46956460e+01 -2.93311353e-02 -2.10715051e-02 -2.43873706e+01
#   3.49654284e+01  2.94933845e+01]
# Generating plot for AAPL...
# Plot saved as 'AAPL_test_predictions.png'
# AAPL analysis completed.
#  AAPL analysis completed.

# %% [markdown]
# **5. Run Analysis for NFLX**

# %%
print("\nRunning analysis for NFLX...")
TICKER_TO_ANALYZE_3 = 'NFLX'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE_3,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" NFLX analysis completed.")
# Out:
# Running analysis for NFLX...
#
# --- Starting Analysis for: NFLX ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 14.414605
#   Weights: [ 2.47382945e+02  1.41618595e-01  8.64724764e-02 -1.06779041e+02
#   1.44930491e+02  1.39792405e+02]
# Method: Custom CG
#   Test MSE: 14.415894
#   Weights: [ 2.47382945e+02  1.41922724e-01  8.56257350e-02 -1.06777898e+02
#   1.44968149e+02  1.39756273e+02]
# Method: Least Squares
#   Test MSE: 14.415038
#   Weights: [ 2.47382945e+02  1.41757218e-01  8.65912574e-02 -1.06779511e+02
#   1.44919915e+02  1.39803369e+02]
# Generating plot for NFLX...
# Plot saved as 'NFLX_test_predictions.png'
# NFLX analysis completed.
#  NFLX analysis completed.

# %% [markdown]
# **6. Run Analysis for SBUX**

# %%
print("\nRunning analysis for SBUX...")
TICKER_TO_ANALYZE_4 = 'SBUX'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE_4,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" SBUX analysis completed.")
# Out:
# Running analysis for SBUX...
#
# --- Starting Analysis for: SBUX ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 0.323637
#   Weights: [ 6.58231926e+01 -2.02255713e-02 -2.72823903e-02 -1.13441730e+01
#   2.08361180e+01  1.36661856e+01]
# Method: Custom CG
#   Test MSE: 0.323674
#   Weights: [ 6.58231963e+01 -2.02848286e-02 -2.74105477e-02 -1.13505706e+01
#   2.08469289e+01  1.36618660e+01]
# Method: Least Squares
#   Test MSE: 0.323665
#   Weights: [ 6.58231963e+01 -2.03022032e-02 -2.74052663e-02 -1.13505866e+01
#   2.08469140e+01  1.36618417e+01]
# Generating plot for SBUX...
# Plot saved as 'SBUX_test_predictions.png'
# SBUX analysis completed.
#  SBUX analysis completed.

# %% [markdown]
# **7. Run Analysis for CSCO**

# %%
print("\nRunning analysis for CSCO...")
TICKER_TO_ANALYZE_5 = 'CSCO'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE_5,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" CSCO analysis completed.")
# Out:
# Running analysis for CSCO...
#
# --- Starting Analysis for: CSCO ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 0.088329
#   Weights: [ 3.73953839e+01  3.17847779e-02  3.78363097e-03 -6.31785902e+00
#   9.04790072e+00  8.28227454e+00]
# Method: Custom CG
#   Test MSE: 0.088330
#   Weights: [ 3.73953839e+01  3.17908311e-02  3.78108915e-03 -6.31785298e+00
#   9.04790640e+00  8.28228166e+00]
# Method: Least Squares
#   Test MSE: 0.088329
#   Weights: [ 3.73953839e+01  3.17848094e-02  3.78363839e-03 -6.31785903e+00
#   9.04790071e+00  8.28227453e+00]
# Generating plot for CSCO...
# Plot saved as 'CSCO_test_predictions.png'
# CSCO analysis completed.
#  CSCO analysis completed.

# %% [markdown]
# **8. Run Analysis for QCOM**

# %%
print("\nRunning analysis for QCOM...")
TICKER_TO_ANALYZE_6 = 'QCOM'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE_6,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" QCOM analysis completed.")
# Out:
# Running analysis for QCOM...
#
# --- Starting Analysis for: QCOM ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 1.777102
#   Weights: [ 7.88523136e+01  4.01506914e-03 -2.49299529e-02 -1.93278609e+01
#   2.52469777e+01  2.47149524e+01]
# Method: Custom CG
#   Test MSE: 1.777050
#   Weights: [ 7.88523114e+01  4.00226035e-03 -2.49707618e-02 -1.93295399e+01
#   2.52496424e+01  2.47139813e+01]
# Method: Least Squares
#   Test MSE: 1.777057
#   Weights: [ 7.88523114e+01  3.99926055e-03 -2.49699667e-02 -1.93295438e+01
#   2.52496385e+01  2.47139772e+01]
# Generating plot for QCOM...
# Plot saved as 'QCOM_test_predictions.png'
# QCOM analysis completed.
#  QCOM analysis completed.

# %% [markdown]
# **9. Run Analysis for META**

# %%
print("\nRunning analysis for META...")
TICKER_TO_ANALYZE_7 = 'META'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE_7,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" META analysis completed.")
# Out:
# Running analysis for META...
#
# --- Starting Analysis for: META ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 4.095183
#   Weights: [ 1.61130209e+02  1.15587968e-01  5.08620146e-02 -4.63186388e+01
#   6.43300925e+01  6.47309220e+01]
# Method: Custom CG
#   Test MSE: 4.095318
#   Weights: [ 1.61130208e+02  1.15589038e-01  5.08617147e-02 -4.63122130e+01
#   6.43265974e+01  6.47279901e+01]
# Method: Least Squares
#   Test MSE: 4.095319
#   Weights: [ 1.61130209e+02  1.15589038e-01  5.08617161e-02 -4.63122130e+01
#   6.43265974e+01  6.47279901e+01]
# Generating plot for META...
# Plot saved as 'META_test_predictions.png'
# META analysis completed.
#  META analysis completed.

# %% [markdown]
# **10. Run Analysis for AMZN**

# %%
print("\nRunning analysis for AMZN...")
TICKER_TO_ANALYZE_8 = 'AMZN'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE_8,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" AMZN analysis completed.")
# Out:
# Running analysis for AMZN...
#
# --- Starting Analysis for: AMZN ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 1.229454
#   Weights: [ 7.16935742e+01  9.83956096e-02 -1.34124378e-02 -3.40816695e+01
#   4.60529107e+01  4.03522545e+01]
# Method: Custom CG
#   Test MSE: 1.229084
#   Weights: [ 7.16935742e+01  9.81286234e-02 -1.34297669e-02 -3.40821139e+01
#   4.60534806e+01  4.03512950e+01]
# Method: Least Squares
#   Test MSE: 1.229454
#   Weights: [ 7.16935742e+01  9.83940752e-02 -1.34123874e-02 -3.40816690e+01
#   4.60529112e+01  4.03522550e+01]
# Generating plot for AMZN...
# Plot saved as 'AMZN_test_predictions.png'
# AMZN analysis completed.
#  AMZN analysis completed.

# %% [markdown]
# **11. Run Analysis for TSLA**

# %%
print("\nRunning analysis for TSLA...")
TICKER_TO_ANALYZE_9 = 'TSLA'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE_9,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" TSLA analysis completed.")
# Out:
# Running analysis for TSLA...
#
# --- Starting Analysis for: TSLA ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 13.912424
#   Weights: [ 5.53353232e+01  2.02358446e-02 -1.25595645e-02 -4.81873006e+01
#   7.54197959e+01  5.63339770e+01]
# Method: Custom CG
#   Test MSE: 13.911703
#   Weights: [ 5.53353233e+01  2.02422529e-02 -1.25615019e-02 -4.81952025e+01
#   7.54236975e+01  5.63379827e+01]
# Method: Least Squares
#   Test MSE: 13.911675
#   Weights: [ 5.53353233e+01  2.02400362e-02 -1.25616695e-02 -4.81952052e+01
#   7.54236949e+01  5.63379799e+01]
# Generating plot for TSLA...
# Plot saved as 'TSLA_test_predictions.png'
# TSLA analysis completed.
#  TSLA analysis completed.

# %% [markdown]
# **12. Run Analysis for AMD**

# %%
print("\nRunning analysis for AMD...")
TICKER_TO_ANALYZE_10 = 'AMD'
TRAIN_TEST_SPLIT_DATE = '2022-01-01'

optimizer.run_analysis(
    ticker=TICKER_TO_ANALYZE_10,
    test_split_date=TRAIN_TEST_SPLIT_DATE
)
print(" AMD analysis completed.")
# Out:
# Running analysis for AMD...
#
# --- Starting Analysis for: AMD ---
# Data split: 1294 train samples, 229 test samples.
#
# Fitting models...
#   Fitting Scipy CG...
#   Fitting Custom CG (with Analytical Alpha)...
#   Fitting Least Squares...
# All models fitted.
#
# --- Model Test Set Results ---
# Method: Scipy CG
#   Test MSE: 1.716967
#   Weights: [ 28.45555717   0.04661492  -0.05343233 -21.93861263  31.68666086
#   24.92890512]
# Method: Custom CG
#   Test MSE: 1.716740
#   Weights: [ 28.45555641   0.04650288  -0.05331875 -21.93779667  31.67578972
#   24.9389017 ]
# Method: Least Squares
#   Test MSE: 1.716799
#   Weights: [ 28.45555641   0.04653438  -0.05330756 -21.93775791  31.67583349
#   24.93892024]
# Generating plot for AMD...
# Plot saved as 'AMD_test_predictions.png'
# AMD analysis completed.
#  AMD analysis completed.
